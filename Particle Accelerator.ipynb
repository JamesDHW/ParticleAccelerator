# %% [markdown]
# ## PART 1 - Project Tasks
#
# 1. Start off with the training sets only
# 2. Inspect all 19 variables by eye and/or with the use of the ($\epsilon\times\rho$) metric. 5 of them are clearly poor discriminators and can be discarded from further consideration. 10 have got some good level of discriminating power and should definitely be kept for the next stage. 4 have intermediate discrimination.
# 3. For the good or good/intermediate discriminators then you can proceed in one of the two ways as discussed above, i.e. optimise all cuts at the same time or one at a time. Your mark from this part of the project will depend, in part, on how well your final cut selection performs.
#
# Your final event selection will be a series of variables and cut values. The following should be clear in your code:
#
# 1. which variables you have used to cut on
# 2. the cut value(s) for each variable
# 3. the order the cuts are applied in (where relevant)

# %%
# ASSESSED CODE REDACTED
# Out:
# done

# %%
# ASSESSED CODE REDACTED
# Out:
# done

# %%
# ASSESSED CODE REDACTED
# Out:
# View all histograms for values of variables? (y/n) y
# View all P*E graphs for values of variables? (y/n) nMax PxE is 0.7931635841977488 in effpully corresponding to bin 18
# Cut left of  18
# Cut the data? (y/n)  yView all histograms for values of variables? (y/n) nView all P*E graphs for values of variables? (y/n) nCut the data? (y/n)  Max PxE is 1.0 in effpullx corresponding to bin 10
# Cut left of  10
# View all histograms for values of variables? (y/n) y
# View all P*E graphs for values of variables? (y/n) nMax PxE is 1.0 in effpully corresponding to bin 0
# Cut left of  0
# Cut the data? (y/n)  nCuts finished. You have made 2 cuts

# %%
# ASSESSED CODE REDACTED
# Out:
# View all histograms for values of variables? (y/n) y

# %% [markdown]
# ## Conclusion
#
# Both data sets were analysed for the best linear cut and both took 2 cuts to reduce the background significantly (PxE=1.0). As can be seen by the histograms, the linear cuts using pseodovariables cuts a high proportion of the background and are very highly discriminating.<br>
# Both data sets used the same two cuts (left of bin 18 for effpully and left of bin 10 effpullx), which is a good indicator that training the first set will work well when using identical cuts to cut data for an unknown mix of background and signal. Using these two cuts is how you would discriminate between signal and background neutrino data (given the same variables) in practice (with no knowledge of what was signal and what was data).
